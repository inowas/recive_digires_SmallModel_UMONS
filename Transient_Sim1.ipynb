# %%
from IPython.display import clear_output, display

import time
import os
import sys
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# run installed version of flopy or add local path
try:
    import flopy
except:
    fpth = os.path.abspath(os.path.join('..', '..'))
    sys.path.append(fpth)
    import flopy

print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('matplotlib version: {}'.format(mpl.__version__))
print('pandas version: {}'.format(pd.__version__))
print('flopy version: {}'.format(flopy.__version__))
# Out:
# flopy is installed in /Users/ralf/.virtualenvs/flopy/lib/python3.7/site-packages/flopy
# 3.7.7 (default, Mar 10 2020, 15:43:33)
# [Clang 11.0.0 (clang-1100.0.33.17)]
# numpy version: 1.18.3
# matplotlib version: 3.2.1
# pandas version: 1.0.3
# flopy version: 3.3.0

# %% [markdown]
# ### Model inputs

# %%
# load the model
project_name = "UMONS_SmallModel_Transient_Sim1"
model_ws = os.path.join('.', "Transient_Sim1")
ml = flopy.modflow.Modflow.load(
    project_name+".mfn", 
    model_ws=model_ws, 
    verbose=True,
    check=False, 
    exe_name="mf2000"
)
# Out:
# Creating new model with name: UMONS_SmallModel_Transient_Sim1
# --------------------------------------------------
#
# Parsing the namefile --> ./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.mfn
#
# --------------------------------------------------
# External unit dictionary:
# {7: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.obs, filetype:OBS, 8: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.chob, filetype:CHOB, 9: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.dis, filetype:DIS, 10: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.ba6, filetype:BAS6, 11: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.lpf, filetype:LPF, 12: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.oc, filetype:OC, 13: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.rch, filetype:RCH, 16: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.wel, filetype:WEL, 14: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.chd, filetype:CHD, 15: filename:./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.pcg, filetype:PCG}
# --------------------------------------------------
#
# ModflowBas6 free format:True
#
# loading dis package file...
#    Loading dis package with:
#       1 layers, 221 rows, 227 columns, and 52 stress periods
#    loading laycbd...
#    loading delr...
#    loading delc...
#    loading top...
#    loading botm...
#       for 1 layers and 0 confining beds
#    loading stress period data...
#        for 52 stress periods
# adding Package:  DIS
#    DIS  package load...success
#    OBS  package load...skipped
# loading flwob package file...
# adding Package:  CHOB
#    CHOB package load...success
# loading bas6 package file...
# adding Package:  BAS6
#    BAS6 package load...success
# loading lpf package file...
#    loading IBCFCB, HDRY, NPLPF...
#    loading LAYTYP...
#    loading LAYAVG...
#    loading CHANI...
#    loading LAYVKA...
#    loading LAYWET...
#    loading hk layer   1...
#    loading hani layer   1...
#    loading vka layer   1...
#    loading ss layer   1...
#    loading sy layer   1...
# Adding UMONS_SmallModel_Transient_Sim1.cbc (unit=40) to the output list.
# adding Package:  LPF
#    LPF  package load...success
# loading oc package file...
# head file name will be generated by flopy
# Adding UMONS_SmallModel_Transient_Sim1.hds (unit=3) to the output list.
# adding Package:  OC
#    OC   package load...success
# loading rch package file...
#    loading rech stress period   1...
#    loading rech stress period   2...
#    loading rech stress period   3...
#    loading rech stress period   4...
#    loading rech stress period   5...
#    loading rech stress period   6...
#    loading rech stress period   7...
#    loading rech stress period   8...
#    loading rech stress period   9...
#    loading rech stress period  10...
#    loading rech stress period  11...
#    loading rech stress period  12...
#    loading rech stress period  13...
#    loading rech stress period  14...
#    loading rech stress period  15...
#    loading rech stress period  16...
#    loading rech stress period  17...
#    loading rech stress period  18...
#    loading rech stress period  19...
#    loading rech stress period  20...
#    loading rech stress period  21...
#    loading rech stress period  22...
#    loading rech stress period  23...
#    loading rech stress period  24...
#    loading rech stress period  25...
#    loading rech stress period  26...
#    loading rech stress period  27...
#    loading rech stress period  28...
#    loading rech stress period  29...
#    loading rech stress period  30...
#    loading rech stress period  31...
#    loading rech stress period  32...
#    loading rech stress period  33...
#    loading rech stress period  34...
#    loading rech stress period  35...
#    loading rech stress period  36...
#    loading rech stress period  37...
#    loading rech stress period  38...
#    loading rech stress period  39...
#    loading rech stress period  40...
#    loading rech stress period  41...
#    loading rech stress period  42...
#    loading rech stress period  43...
#    loading rech stress period  44...
#    loading rech stress period  45...
#    loading rech stress period  46...
#    loading rech stress period  47...
#    loading rech stress period  48...
#    loading rech stress period  49...
#    loading rech stress period  50...
#    loading rech stress period  51...
#    loading rech stress period  52...
# adding Package:  RCH
#    RCH  package load...success
# loading wel package file...
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     1
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     2
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     3
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     4
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     5
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     6
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     7
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     8
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     9
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    10
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    11
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    12
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    13
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    14
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    15
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    16
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    17
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    18
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    19
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    20
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    21
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    22
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    23
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    24
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    25
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    26
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    27
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    28
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    29
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    30
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    31
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    32
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    33
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    34
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    35
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    36
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    37
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    38
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    39
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    40
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    41
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    42
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    43
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    44
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    45
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    46
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    47
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    48
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    49
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    50
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    51
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper    52
# adding Package:  WEL
#    WEL  package load...success
# loading chd package file...
#    implicit ipakcb in ./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.chd
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     1
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     2
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     3
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     4
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     5
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     6
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     7
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     8
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     9
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    10
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    11
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    12
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    13
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    14
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    15
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    16
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    17
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    18
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    19
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    20
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    21
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    22
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    23
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    24
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    25
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    26
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    27
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    28
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    29
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    30
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    31
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    32
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    33
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    34
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    35
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    36
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    37
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    38
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    39
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    40
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    41
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    42
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    43
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    44
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    45
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    46
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    47
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    48
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    49
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    50
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    51
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper    52
# adding Package:  CHD
#
# CHD PACKAGE DATA VALIDATION:
#   No errors or warnings encountered.
#
#    CHD  package load...success
# loading pcg package file...
# adding Package:  PCG
#    PCG  package load...success
# Warning: external file unit 140 does not exist in ext_unit_dict.
# Warning: external file unit 40 does not exist in ext_unit_dict.
# Warning: external file unit 3 does not exist in ext_unit_dict.
# Warning: external file unit 0 does not exist in ext_unit_dict.
#
#    The following 9 packages were successfully loaded.
#       UMONS_SmallModel_Transient_Sim1.dis
#       UMONS_SmallModel_Transient_Sim1.chob
#       UMONS_SmallModel_Transient_Sim1.ba6
#       UMONS_SmallModel_Transient_Sim1.lpf
#       UMONS_SmallModel_Transient_Sim1.oc
#       UMONS_SmallModel_Transient_Sim1.rch
#       UMONS_SmallModel_Transient_Sim1.wel
#       UMONS_SmallModel_Transient_Sim1.chd
#       UMONS_SmallModel_Transient_Sim1.pcg
#    The following 1 packages were not loaded.
#       UMONS_SmallModel_Transient_Sim1.obs

# %%
ml.dis.sr
# Out:
# xul:0; yul:11017.70536; rotation:0; proj4_str:None; units:meters; lenuni:2; length_multiplier:1.0

# %%
ml.lpf.plot()
# Out:
# plotting LPF package Util3d instance: hk
# plotting LPF package Util3d instance: hani
# plotting LPF package Util3d instance: vka
# plotting LPF package Util3d instance: ss
# plotting LPF package Util3d instance: sy
# plotting LPF package Util3d instance: vkcb
# plotting LPF package Util3d instance: wetdry
# [<matplotlib.axes._subplots.AxesSubplot at 0x11ff05b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1200c76d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12352c190>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x123802c90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1201d3ed0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x123db1a10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1239674d0>]

# %%
ml.dis.plot()
# Out:
# plotting DIS package Util2d instance: top
# plotting DIS package Util3d instance: botm
# plotting DIS package Util3d instance: _ModflowDis__thickness
# [<matplotlib.axes._subplots.AxesSubplot at 0x125399c50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1260ea0d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1263beb90>]

# %%
ml.dis.export(os.path.join(model_ws, project_name+".shp"))
# Out:
# wrote ./Transient_Sim1/UMONS_SmallModel_Transient_Sim1.shp

# %%
ml.write_input()
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  CHOB
#    Package:  BAS6
#    Package:  LPF
#    Package:  OC
#    Package:  RCH
#    Package:  WEL
#    Package:  CHD
#    Package:  PCG

# %%
ml.run_model()
# Out:
# FloPy is using the following  executable to run the model: /usr/local/bin/mf2000
#
#                                   MODFLOW-2000
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.19.01 03/25/2010
#
#  Using NAME file: UMONS_SmallModel_Transient_Sim1.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/04/30 15:45:45
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2020/04/30 15:45:51
#  Elapsed run time:  5.786 Seconds
#
#  Normal termination of MODFLOW-2000
# (True, [])

# %% [markdown]
# ### Output inspection
#
# First, lets look at the list file

# %%
mfl = flopy.utils.MfListBudget(os.path.join(model_ws, project_name+".list"))
df_flux, df_vol = mfl.get_dataframes(start_datetime="01-01-1979")
df_flux
# Out:
#                             STORAGE_IN  CONSTANT_HEAD_IN  WELLS_IN  \
# 1979-01-01 16:47:59.998970    0.000000            0.0000       0.0
# 1979-01-02 09:35:59.997940    0.000000            0.0000       0.0
# 1979-01-03 02:23:59.991760    0.000000            0.0000       0.0
# 1979-01-03 19:11:59.995880    0.000000            0.0000       0.0
# 1979-01-04 12:00:00.000000    0.000000            0.0000       0.0
# ...                                ...               ...       ...
# 1979-12-28 04:48:01.054688    0.017050            0.4431       0.0
# 1979-12-28 21:35:59.472656    0.016533            0.4432       0.0
# 1979-12-29 14:24:00.527344    0.017362            0.4433       0.0
# 1979-12-30 07:11:58.945312    0.017623            0.4433       0.0
# 1979-12-31 00:00:00.000000    0.016973            0.4434       0.0
#
#                             RECHARGE_IN  TOTAL_IN   STORAGE_OUT  \
# 1979-01-01 16:47:59.998970       0.4102    0.4102  0.000000e+00
# 1979-01-02 09:35:59.997940       0.4102    0.4102  0.000000e+00
# 1979-01-03 02:23:59.991760       0.4102    0.4102  0.000000e+00
# 1979-01-03 19:11:59.995880       0.4102    0.4102  0.000000e+00
# 1979-01-04 12:00:00.000000       0.4102    0.4102  0.000000e+00
# ...                                 ...       ...           ...
# 1979-12-28 04:48:01.054688       0.4102    0.8704  8.512900e-08
# 1979-12-28 21:35:59.472656       0.4102    0.8700  7.625600e-08
# 1979-12-29 14:24:00.527344       0.4102    0.8708  2.561100e-09
# 1979-12-30 07:11:58.945312       0.4102    0.8712  8.021000e-08
# 1979-12-31 00:00:00.000000       0.4102    0.8706  2.120900e-08
#
#                             CONSTANT_HEAD_OUT  WELLS_OUT  RECHARGE_OUT  \
# 1979-01-01 16:47:59.998970           0.410400     0.0000           0.0
# 1979-01-02 09:35:59.997940           0.410400     0.0000           0.0
# 1979-01-03 02:23:59.991760           0.410400     0.0000           0.0
# 1979-01-03 19:11:59.995880           0.410400     0.0000           0.0
# 1979-01-04 12:00:00.000000           0.410400     0.0000           0.0
# ...                                       ...        ...           ...
# 1979-12-28 04:48:01.054688           0.016918     0.8559           0.0
# 1979-12-28 21:35:59.472656           0.016907     0.8559           0.0
# 1979-12-29 14:24:00.527344           0.016897     0.8559           0.0
# 1979-12-30 07:11:58.945312           0.016886     0.8559           0.0
# 1979-12-31 00:00:00.000000           0.016875     0.8559           0.0
#
#                             TOTAL_OUT    IN-OUT  PERCENT_DISCREPANCY
# 1979-01-01 16:47:59.998970     0.4104 -0.000206                -0.05
# 1979-01-02 09:35:59.997940     0.4104 -0.000201                -0.05
# 1979-01-03 02:23:59.991760     0.4104 -0.000208                -0.05
# 1979-01-03 19:11:59.995880     0.4104 -0.000207                -0.05
# 1979-01-04 12:00:00.000000     0.4104 -0.000206                -0.05
# ...                               ...       ...                  ...
# 1979-12-28 04:48:01.054688     0.8728 -0.002407                -0.28
# 1979-12-28 21:35:59.472656     0.8728 -0.002854                -0.33
# 1979-12-29 14:24:00.527344     0.8728 -0.001953                -0.22
# 1979-12-30 07:11:58.945312     0.8728 -0.001618                -0.19
# 1979-12-31 00:00:00.000000     0.8728 -0.002197                -0.25
#
# [520 rows x 12 columns]

# %%
groups = df_flux.groupby(lambda x:x.split('_')[-1],axis=1).groups
df_flux_in = df_flux.loc[:,groups["IN"]]
df_flux_in.columns = df_flux_in.columns.map(lambda x:x.split('_')[0])

df_flux_out = df_flux.loc[:,groups["OUT"]]
df_flux_out.columns = df_flux_out.columns.map(lambda x:x.split('_')[0])


df_flux_delta = df_flux_in - df_flux_out
df_flux_delta.iloc[-1,:].plot(kind="bar",figsize=(10,10),grid=True);

# %% [markdown]
# ### Let's look at the simulated head

# %%
# if you pass the model instance, then the plots will be offset and rotated
h = flopy.utils.HeadFile(os.path.join(model_ws, project_name+".hds"), model=ml)
h.times
# Out:
# [60480.0,
#  120960.0,
#  181440.0,
#  241920.0,
#  302400.0,
#  362880.0,
#  423360.0,
#  483840.0,
#  544320.0,
#  604800.0,
#  665280.0,
#  725760.0,
#  786240.0,
#  846720.0,
#  907200.0,
#  967680.0,
#  1028160.0,
#  1088640.0,
#  1149120.0,
#  1209600.0,
#  1270080.0,
#  1330560.0,
#  1391040.0,
#  1451520.0,
#  1512000.0,
#  1572480.0,
#  1632960.0,
#  1693440.0,
#  22317120.0,
#  22377600.0,
#  22438080.0,
#  22498560.0,
#  22559040.0,
#  22619520.0,
#  22680000.0,
#  22740480.0,
#  22800960.0,
#  22861440.0,
#  22921920.0,
#  22982400.0,
#  23042880.0,
#  23103360.0,
#  23163840.0,
#  23224320.0,
#  23284800.0,
#  23345280.0,
#  23405760.0,
#  23466240.0,
#  23526720.0,
#  23587200.0,
#  23647680.0,
#  23708160.0,
#  23768640.0,
#  23829120.0,
#  23889600.0,
#  23950080.0,
#  24010560.0,
#  24071040.0,
#  24131520.0,
#  24192000.0,
#  24252480.0,
#  24312960.0,
#  24373440.0,
#  24433920.0,
#  24494400.0,
#  24554880.0,
#  24615360.0,
#  24675840.0,
#  24736320.0,
#  24796800.0,
#  24857280.0,
#  24917760.0,
#  24978240.0,
#  25038720.0,
#  25099200.0,
#  25159680.0,
#  25220160.0,
#  25280640.0,
#  25341120.0,
#  25401600.0,
#  25462080.0,
#  25522560.0,
#  25583040.0,
#  25643520.0,
#  25704000.0,
#  25764480.0,
#  25824960.0,
#  25885440.0,
#  25945920.0,
#  26006400.0,
#  26066880.0,
#  26127360.0,
#  26187840.0,
#  26248320.0,
#  26308800.0,
#  26369280.0,
#  26429760.0,
#  26490240.0,
#  26550720.0,
#  26611200.0,
#  26671680.0,
#  26732160.0,
#  26792640.0,
#  26853120.0,
#  26913600.0,
#  26974080.0,
#  27034560.0,
#  27095040.0,
#  27155520.0,
#  27216000.0,
#  27276480.0,
#  27336960.0,
#  27397440.0,
#  27457920.0,
#  27518400.0,
#  27578880.0,
#  27639360.0,
#  27699840.0,
#  27760320.0,
#  27820800.0,
#  27881280.0,
#  27941760.0,
#  28002240.0,
#  28062720.0,
#  28123200.0,
#  28183680.0,
#  28244160.0,
#  28304640.0,
#  28365120.0,
#  28425600.0,
#  28486080.0,
#  28546560.0,
#  28607040.0,
#  28667520.0,
#  28728000.0,
#  28788480.0,
#  28848960.0,
#  28909440.0,
#  28969920.0,
#  29030400.0,
#  29090880.0,
#  29151360.0,
#  29211840.0,
#  29272320.0,
#  29332800.0,
#  29393280.0,
#  29453760.0,
#  29514240.0,
#  29574720.0,
#  29635200.0,
#  29695680.0,
#  29756160.0,
#  29816640.0,
#  29877120.0,
#  29937600.0,
#  29998080.0,
#  30058560.0,
#  30119040.0,
#  30179520.0,
#  30240000.0,
#  30300480.0,
#  30360960.0,
#  30421440.0,
#  30481920.0,
#  30542400.0,
#  30602880.0,
#  30663360.0,
#  30723840.0,
#  30784320.0,
#  30844800.0,
#  30905280.0,
#  30965760.0,
#  31026240.0,
#  31086720.0,
#  31147200.0,
#  31207680.0,
#  31268160.0,
#  31328640.0,
#  31389120.0,
#  31449600.0]

# %%
h.plot(totim=h.times[-1], contour=True, grid=False, colorbar=True, figsize=(10,10));

# %% [markdown]
# ### Write heads to shapefile

# %%
#let's write these heads to shapefile
h.to_shapefile(os.path.join(model_ws, project_name+"_head.shp"))
# Out:
# wrote ./Transient_Sim1/UMONS_SmallModel_Transient_Sim1_head.shp

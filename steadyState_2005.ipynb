# %%
from IPython.display import clear_output, display

import time
import os
import sys
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# run installed version of flopy or add local path
try:
    import flopy
except:
    fpth = os.path.abspath(os.path.join('..', '..'))
    sys.path.append(fpth)
    import flopy

print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('matplotlib version: {}'.format(mpl.__version__))
print('pandas version: {}'.format(pd.__version__))
print('flopy version: {}'.format(flopy.__version__))
# Out:
# flopy is installed in /Users/ralf/.virtualenvs/flopy/lib/python3.7/site-packages/flopy
# 3.7.7 (default, Mar 10 2020, 15:43:33)
# [Clang 11.0.0 (clang-1100.0.33.17)]
# numpy version: 1.18.3
# matplotlib version: 3.2.1
# pandas version: 1.0.3
# flopy version: 3.3.0

# %% [markdown]
# ### Model inputs

# %%
# load the model
project_name = "UMONS_SmallModel_SteadyState_mf2005"
model_ws = os.path.join('.', "SteadyState_mf2005")
ml = flopy.modflow.Modflow.load(
    project_name+".mfn", 
    model_ws=model_ws, 
    verbose=True,
    check=False, 
    exe_name="mf2005"
)
# Out:
# Creating new model with name: UMONS_SmallModel_SteadyState_mf2005
# --------------------------------------------------
#
# Parsing the namefile --> ./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.mfn
#
# --------------------------------------------------
# External unit dictionary:
# {9: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.dis, filetype:DIS, 10: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.ba6, filetype:BAS6, 11: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.lpf, filetype:LPF, 12: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.oc, filetype:OC, 13: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.rch, filetype:RCH, 16: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.wel, filetype:WEL, 14: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.chd, filetype:CHD, 15: filename:./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.pcg, filetype:PCG}
# --------------------------------------------------
#
# ModflowBas6 free format:True
#
# loading dis package file...
#    Loading dis package with:
#       1 layers, 221 rows, 227 columns, and 1 stress periods
#    loading laycbd...
#    loading delr...
#    loading delc...
#    loading top...
#    loading botm...
#       for 1 layers and 0 confining beds
#    loading stress period data...
#        for 1 stress periods
# adding Package:  DIS
#    DIS  package load...success
# loading bas6 package file...
# adding Package:  BAS6
#    BAS6 package load...success
# loading lpf package file...
#    loading IBCFCB, HDRY, NPLPF...
#    loading LAYTYP...
#    loading LAYAVG...
#    loading CHANI...
#    loading LAYVKA...
#    loading LAYWET...
#    loading hk layer   1...
#    loading hani layer   1...
#    loading vka layer   1...
# Adding UMONS_SmallModel_SteadyState_mf2005.cbc (unit=40) to the output list.
# adding Package:  LPF
#    LPF  package load...success
# loading oc package file...
# head file name will be generated by flopy
# Adding UMONS_SmallModel_SteadyState_mf2005.hds (unit=3) to the output list.
# adding Package:  OC
#    OC   package load...success
# loading rch package file...
#    loading rech stress period   1...
# adding Package:  RCH
#    RCH  package load...success
# loading wel package file...
#    loading <class 'flopy.modflow.mfwel.ModflowWel'> for kper     1
# adding Package:  WEL
#    WEL  package load...success
# loading chd package file...
#    implicit ipakcb in ./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.chd
#    loading <class 'flopy.modflow.mfchd.ModflowChd'> for kper     1
# adding Package:  CHD
#
# CHD PACKAGE DATA VALIDATION:
#   No errors or warnings encountered.
#
#    CHD  package load...success
# loading pcg package file...
# adding Package:  PCG
#    PCG  package load...success
# Warning: external file unit 40 does not exist in ext_unit_dict.
# Warning: external file unit 3 does not exist in ext_unit_dict.
# Warning: external file unit 0 does not exist in ext_unit_dict.
#
#    The following 8 packages were successfully loaded.
#       UMONS_SmallModel_SteadyState_mf2005.dis
#       UMONS_SmallModel_SteadyState_mf2005.ba6
#       UMONS_SmallModel_SteadyState_mf2005.lpf
#       UMONS_SmallModel_SteadyState_mf2005.oc
#       UMONS_SmallModel_SteadyState_mf2005.rch
#       UMONS_SmallModel_SteadyState_mf2005.wel
#       UMONS_SmallModel_SteadyState_mf2005.chd
#       UMONS_SmallModel_SteadyState_mf2005.pcg

# %%
ml.dis.sr
# Out:
# xul:0; yul:11017.70536; rotation:0; proj4_str:None; units:meters; lenuni:2; length_multiplier:1.0

# %%
ml.lpf.plot()
# Out:
# plotting LPF package Util3d instance: hk
# plotting LPF package Util3d instance: hani
# plotting LPF package Util3d instance: vka
# plotting LPF package Util3d instance: ss
# plotting LPF package Util3d instance: sy
# plotting LPF package Util3d instance: vkcb
# plotting LPF package Util3d instance: wetdry
# [<matplotlib.axes._subplots.AxesSubplot at 0x11b58f1d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11ddf4410>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e0cb350>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e3a0e10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x102c95d90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e9503d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11eab3c90>]

# %%
ml.dis.plot()
# Out:
# plotting DIS package Util2d instance: top
# plotting DIS package Util3d instance: botm
# plotting DIS package Util3d instance: _ModflowDis__thickness
# [<matplotlib.axes._subplots.AxesSubplot at 0x1206d09d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x120cb3990>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x120f8d490>]

# %%
ml.dis.export(os.path.join(model_ws, project_name+".shp"))
# Out:
# wrote ./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005.shp

# %%
ml.write_input()
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  LPF
#    Package:  OC
#    Package:  RCH
#    Package:  WEL
#    Package:  CHD
#    Package:  PCG

# %%
ml.run_model()
# Out:
# FloPy is using the following  executable to run the model: /usr/local/bin/mf2005
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: UMONS_SmallModel_SteadyState_mf2005.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2020/04/30 15:45:14
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2020/04/30 15:45:14
#  Elapsed run time:  0.249 Seconds
#
#   Normal termination of simulation
# (True, [])

# %% [markdown]
# ### Output inspection
#
# First, lets look at the list file

# %%
mfl = flopy.utils.MfListBudget(os.path.join(model_ws, project_name+".list"))
df_flux, df_vol = mfl.get_dataframes(start_datetime="01-01-1979")
df_flux
# Out:
#                             STORAGE_IN  CONSTANT_HEAD_IN  WELLS_IN  \
# 1979-01-01 00:00:01.000002         0.0            0.4442       0.0
#
#                             RECHARGE_IN  TOTAL_IN  STORAGE_OUT  \
# 1979-01-01 00:00:01.000002         0.41    0.8542          0.0
#
#                             CONSTANT_HEAD_OUT  WELLS_OUT  RECHARGE_OUT  \
# 1979-01-01 00:00:01.000002           0.013444     0.8406           0.0
#
#                             TOTAL_OUT    IN-OUT  PERCENT_DISCREPANCY
# 1979-01-01 00:00:01.000002      0.854  0.000201                 0.02

# %%
groups = df_flux.groupby(lambda x:x.split('_')[-1],axis=1).groups
df_flux_in = df_flux.loc[:,groups["IN"]]
df_flux_in.columns = df_flux_in.columns.map(lambda x:x.split('_')[0])

df_flux_out = df_flux.loc[:,groups["OUT"]]
df_flux_out.columns = df_flux_out.columns.map(lambda x:x.split('_')[0])


df_flux_delta = df_flux_in - df_flux_out
df_flux_delta.iloc[-1,:].plot(kind="bar",figsize=(10,10),grid=True);

# %% [markdown]
# ### Let's look at the simulated head

# %%
# if you pass the model instance, then the plots will be offset and rotated
h = flopy.utils.HeadFile(os.path.join(model_ws, project_name+".hds"), model=ml)
h.times
# Out:
# [1.0]

# %%
h.plot(totim=1, contour=True, grid=False, colorbar=True, figsize=(10,10));

# %% [markdown]
# ### Write heads to shapefile

# %%
#let's write these heads to shapefile
h.to_shapefile(os.path.join(model_ws, project_name+"_head.shp"))
# Out:
# wrote ./SteadyState_mf2005/UMONS_SmallModel_SteadyState_mf2005_head.shp
